# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
warnings.filterwarnings("ignore")

# %%
a = pd.read_csv("E:/Data Science/ETL_HIVE/Git_Hub_Project/EDA/attrition.csv")

# %%
a.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
pd.set_option('display.max_columns',35)

# %%
a.shape
# Out:
# (1470, 35)

# %%
a.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ### Missing Value Check

# %%
a.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### Converting target variable (Attrition) to binary

# %%
a['Attrition'] = a['Attrition'].map({'Yes':1,'No':0})

# %%
a.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %% [markdown]
# #### Finding unique values for Education Fields

# %%
print(a.Education.unique())
print(a.EducationField.unique())
# Out:
# [2 1 4 3 5]
# ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']

# %%
a['Education'] = a['Education'].map({1: 'High School',2:'Undergrad',3:'Graduate',4:'Post Graduate',5:'Doctorate'})

# %% [markdown]
# #### Finding unique values for Rating Factor columns

# %%
print(a.JobInvolvement.unique())
print(a.JobSatisfaction.unique())
print(a.PerformanceRating.unique())
# Out:
# [3 2 4 1]
# [4 2 3 1]
# [3 4]

# %%
cols = ["JobInvolvement", "JobSatisfaction", "PerformanceRating"]

for col in cols:
    a[col].replace({1 : "Low",2 : "Medium",3 : "High",4 : "Very High"}, inplace = True)
a.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome      Education EducationField  EmployeeCount  \
# 0                 1      Undergrad  Life Sciences              1
# 1                 8    High School  Life Sciences              1
# 2                 2      Undergrad          Other              1
# 3                 3  Post Graduate  Life Sciences              1
# 4                 2    High School        Medical              1
#
#    EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate JobInvolvement  \
# ...

# %% [markdown]
# #### Checking non-statistical important value

# %%
a.EmployeeCount.value_counts()
# Out:
# 1    1470
# Name: EmployeeCount, dtype: int64

# %%
a.Over18.value_counts()
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %%
a.StandardHours.value_counts()
# Out:
# 80    1470
# Name: StandardHours, dtype: int64

# %%
a = a.drop(labels=['EmployeeCount','Over18','StandardHours'],axis=1)

# %%
a.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome      Education EducationField  EmployeeNumber  \
# 0                 1      Undergrad  Life Sciences               1
# 1                 8    High School  Life Sciences               2
# 2                 2      Undergrad          Other               4
# 3                 3  Post Graduate  Life Sciences               5
# 4                 2    High School        Medical               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# #### Checking all Attrition Features and their unique values

# %%
attFeatures = []

for i in a.columns:
    attFeatures.append([i, a[i].nunique(),a[i].drop_duplicates().values])
    
    q = pd.DataFrame(attFeatures,columns=['Features', 'Unique Number', 'Values'])

# %%
q
# Out:
#                     Features  Unique Number  \
# 0                        Age             43
# 1                  Attrition              2
# 2             BusinessTravel              3
# 3                  DailyRate            886
# 4                 Department              3
# 5           DistanceFromHome             29
# 6                  Education              5
# 7             EducationField              6
# 8             EmployeeNumber           1470
# 9    EnvironmentSatisfaction              4
# 10                    Gender              2
# 11                HourlyRate             71
# 12            JobInvolvement              4
# 13                  JobLevel              5
# 14                   JobRole              9
# 15           JobSatisfaction              4
# 16             MaritalStatus              3
# 17             MonthlyIncome           1349
# 18               MonthlyRate           1427
# 19        NumCompaniesWorked             10
# ...

# %% [markdown]
# ### Data Visualization

# %%
cat = []
con = []

for i in a.columns:
    if a[i].dtypes=='object':
        cat.append(i)
    else:
        con.append(i)

# %% [markdown]
# ### Attrition Rate

# %%
plt.figure(figsize=(14,4))
plt.subplot(1,2,1)
a.Attrition.value_counts().plot(kind='pie',autopct='%.1f%%')  
plt.subplot(1,2,2)
sb.countplot(a.Attrition)
x = pd.DataFrame(a.Attrition.value_counts())
x
# Out:
#    Attrition
# 0       1233
# 1        237

# %% [markdown]
# ### Travel Readiness

# %%
plt.figure(figsize=(14,4))
plt.subplot(1,2,1)
a.BusinessTravel.value_counts().plot(kind='pie',autopct='%.1f%%')  
plt.subplot(1,2,2)
sb.countplot(a.BusinessTravel)
x = pd.DataFrame(a.BusinessTravel.value_counts())
x
# Out:
#                    BusinessTravel
# Travel_Rarely                1043
# Travel_Frequently             277
# Non-Travel                    150

# %% [markdown]
# ### Count by Department

# %%
plt.figure(figsize=(14,4))
plt.subplot(1,2,1)
a.Department.value_counts().plot(kind='pie',autopct='%.1f%%')  
plt.subplot(1,2,2)
sb.countplot(a.Department)
x = pd.DataFrame(a.Department.value_counts())
x
# Out:
#                         Department
# Research & Development         961
# Sales                          446
# Human Resources                 63

# %% [markdown]
# - Most of the employees are from the R&D Department

# %% [markdown]
# ### Education Level

# %%
plt.figure(figsize=(14,4))
plt.subplot(1,2,1)
a.Education.value_counts().plot(kind='pie',autopct='%.1f%%')  
plt.subplot(1,2,2)
sb.countplot(a.Education)
x = pd.DataFrame(a.Education.value_counts())
x
# Out:
#                Education
# Graduate             572
# Post Graduate        398
# Undergrad            282
# High School          170
# Doctorate             48

# %% [markdown]
# ### Count by Education Field

# %%
plt.figure(figsize=(14,4))
plt.subplot(1,2,1)
a.EducationField.value_counts().plot(kind='pie',autopct='%.1f%%')  
plt.subplot(1,2,2)
sb.countplot(a.EducationField)
x = pd.DataFrame(a.EducationField.value_counts())
x
# Out:
#                   EducationField
# Life Sciences                606
# Medical                      464
# Marketing                    159
# Technical Degree             132
# Other                         82
# Human Resources               27

# %% [markdown]
# ### Counts by JobRole

# %%
plt.figure(figsize=(14,7))
a.JobRole.value_counts().plot(kind='barh')
x = pd.DataFrame(a.JobRole.value_counts())
x
# Out:
#                            JobRole
# Sales Executive                326
# Research Scientist             292
# Laboratory Technician          259
# Manufacturing Director         145
# Healthcare Representative      131
# Manager                        102
# Sales Representative            83
# Research Director               80
# Human Resources                 52

# %% [markdown]
# 1. Correlation_Matrix using HeatMap

# %%
import matplotlib.pyplot as plt
import seaborn as sb

plt.figure(figsize=(20,20))
sb.heatmap(a[con].corr(),annot=True,cmap='twilight_shifted',fmt= '.1f')
# Out:
# <AxesSubplot:>

# %% [markdown]
#  * Age and no.of years of Experience are highly correlated.
#  * Income is highly correlated with working hours
#  * Salary hike is highly correlated with Performance Bonus

# %%
a.Attrition.value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
stayed = a[a['Attrition']==0].describe()
stayed
# Out:
#                Age  Attrition    DailyRate  DistanceFromHome  EmployeeNumber  \
# count  1233.000000     1233.0  1233.000000       1233.000000     1233.000000
# mean     37.561233        0.0   812.504461          8.915653     1027.656123
# std       8.888360        0.0   403.208379          8.012633      606.217074
# min      18.000000        0.0   102.000000          1.000000        2.000000
# 25%      31.000000        0.0   477.000000          2.000000      483.000000
# 50%      36.000000        0.0   817.000000          7.000000     1022.000000
# 75%      43.000000        0.0  1176.000000         13.000000     1574.000000
# max      60.000000        0.0  1499.000000         29.000000     2068.000000
#
#        EnvironmentSatisfaction   HourlyRate     JobLevel  MonthlyIncome  \
# count              1233.000000  1233.000000  1233.000000    1233.000000
# mean                  2.771290    65.952149     2.145985    6832.739659
# ...

# %%
left = a[a['Attrition']==1].describe()
left
# Out:
#               Age  Attrition    DailyRate  DistanceFromHome  EmployeeNumber  \
# count  237.000000      237.0   237.000000        237.000000      237.000000
# mean    33.607595        1.0   750.362869         10.632911     1010.345992
# std      9.689350        0.0   401.899519          8.452525      580.750572
# min     18.000000        1.0   103.000000          1.000000        1.000000
# 25%     28.000000        1.0   408.000000          3.000000      514.000000
# 50%     32.000000        1.0   699.000000          9.000000     1017.000000
# 75%     39.000000        1.0  1092.000000         17.000000     1486.000000
# max     58.000000        1.0  1496.000000         29.000000     2055.000000
#
#        EnvironmentSatisfaction  HourlyRate    JobLevel  MonthlyIncome  \
# count               237.000000  237.000000  237.000000     237.000000
# mean                  2.464135   65.573840    1.637131    4787.092827
# std                   1.169791   20.099958    0.940594    3640.210367
# ...

# %%
b = stayed.iloc[1:2,:]

# %%
c = left.iloc[1:2,:]

# %%
comparison = pd.concat([b,c])
comparison.index = ['stayed_mean','left_mean']
comparison
# Out:
#                    Age  Attrition   DailyRate  DistanceFromHome  \
# stayed_mean  37.561233        0.0  812.504461          8.915653
# left_mean    33.607595        1.0  750.362869         10.632911
#
#              EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobLevel  \
# stayed_mean     1027.656123                 2.771290   65.952149  2.145985
# left_mean       1010.345992                 2.464135   65.573840  1.637131
#
#              MonthlyIncome   MonthlyRate  NumCompaniesWorked  \
# stayed_mean    6832.739659  14265.779400            2.645580
# left_mean      4787.092827  14559.308017            2.940928
#
#              PercentSalaryHike  RelationshipSatisfaction  StockOptionLevel  \
# stayed_mean          15.231144                  2.733982          0.845093
# left_mean            15.097046                  2.599156          0.527426
#
#              TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# ...

# %% [markdown]
# - Mean age of the employees who stayed is higher compared to who left
# - DailyRate of employees who stayed is higher
# - 'DistanceFromHome': Employees who stayed live closer to home
# - 'EnvironmentSatisfaction' & 'JobSatisfaction': Employees who stayed are generally more satisifed with their jobs
# - 'StockOptionLevel': Employees who stayed tend to have higher stock option level

# %% [markdown]
# ### Minimum and Maximum

# %%
w = []
for i in con:
    if a[i].nunique()>30:
        w.append(i)

# %%
a[w].describe().loc[['min','max']]
# Out:
#       Age  DailyRate  EmployeeNumber  HourlyRate  MonthlyIncome  MonthlyRate  \
# min  18.0      102.0             1.0        30.0         1009.0       2094.0
# max  60.0     1499.0          2068.0       100.0        19999.0      26999.0
#
#      TotalWorkingYears  YearsAtCompany
# min                0.0             0.0
# max               40.0            40.0

# %% [markdown]
# ### Finding Outliers

# %%
lst = ['Age','DailyRate','DistanceFromHome','HourlyRate','MonthlyIncome','MonthlyRate']
plt.figure(figsize=(15,15))
m = 1

for i in lst:
    plt.subplot(3,3,m)
    sb.boxplot(a[i])
    m = m +1

# %% [markdown]
# ### Attrition by Education Level

# %%
sb.countplot(a.Education,hue = a.Attrition)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %% [markdown]
# - Mostly Graduate employees seem to be leaving the company

# %% [markdown]
# ### Attrition by Job Involement

# %%
sb.countplot(a.JobInvolvement,hue = a.Attrition)
# Out:
# <AxesSubplot:xlabel='JobInvolvement', ylabel='count'>

# %% [markdown]
# - Employees with Job Involvement between low to moderate tend to leave the company, while there is less attrition between high and very high level job involvement.

# %% [markdown]
# ### Attrition by Job Level

# %%
sb.countplot(a.JobLevel,hue = a.Attrition)
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='count'>

# %% [markdown]
# - Mostly Employees between junior and associate level tend to leave the company more than compared to others.

# %% [markdown]
# ### Attrition by Salary Hike

# %%
sb.countplot(a.PercentSalaryHike,hue = a.Attrition)
# Out:
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='count'>

# %% [markdown]
# - Employees who receive hikes between 11-14% tend to leave the company more than others with higher Salary hike percentage.

# %% [markdown]
# ### Attrition by Age

# %%
plt.figure(figsize=(20,5))
sb.countplot(a.Age, hue=a.Attrition)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# - Majority of the employees who leave the company are less than 40yrs of age.

# %% [markdown]
# ### Attrition by Specific Job Role

# %%
plt.figure(figsize=(20,20))
pd.crosstab(a.JobRole,a.Attrition).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='JobRole'>

# %%
c = pd.crosstab(a.JobRole,a.Attrition)
c['Attrition_Ratio']=c[1]/c[0]
c.sort_values(by=['Attrition_Ratio'],ascending=False)
# Out:
# Attrition                    0   1  Attrition_Ratio
# JobRole
# Sales Representative        50  33         0.660000
# Laboratory Technician      197  62         0.314721
# Human Resources             40  12         0.300000
# Sales Executive            269  57         0.211896
# Research Scientist         245  47         0.191837
# Manufacturing Director     135  10         0.074074
# Healthcare Representative  122   9         0.073770
# Manager                     97   5         0.051546
# Research Director           78   2         0.025641

# %% [markdown]
# - Sales Respresentative has the highest attrition rate while Research Director has low Attrition Rate

# %%
plt.figure(figsize=(20,10))
sb.boxplot(a.JobRole,a.MonthlyIncome)
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='MonthlyIncome'>

# %% [markdown]
# - As there is less salary to Sales Representative, the attrition for this job role is at higher side.
